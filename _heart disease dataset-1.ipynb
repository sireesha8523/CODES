# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (1.37.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from streamlit) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from streamlit) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: jinja2 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\neses\new folder\new folder\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,roc_auc_score,confusion_matrix

# %%
### load dataset
data=pd.read_csv(r"C:\Users\neses\OneDrive\Documents\Heart_Disease_Dataset.csv")

# %%
## check top rows
data.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0          Yes  14.96     Yes             Yes     No               7
# 1          Yes  36.93     Yes             Yes     No               3
# 2           No  18.70     Yes              No    Yes              26
# 3          Yes  31.43     Yes             Yes    Yes              24
# 4          Yes  75.64      No              No    Yes               2
#
#    MentalHealth DiffWalking     Sex AgeCategory  \
# 0             6         Yes  Female       25-29
# 1            10          No  Female       30-34
# 2            15          No    Male       70-74
# 3            20          No  Female       40-44
# 4            29          No    Male       35-39
#
#                              Race                 Diabetic PhysicalActivity  \
# 0                           White                      Yes              Yes
# 1                        Hispanic  No, borderline diabetes              Yes
# 2                        Hispanic                       No               No
# 3  American Indian/Alaskan Native  No, borderline diabetes               No
# 4                           White                       No              Yes
#
#    GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0       Fair       17.1    Yes           Yes        Yes
# 1       Poor        2.7    Yes            No         No
# 2       Poor       15.6    Yes           Yes        Yes
# 3       Fair        1.4     No            No        Yes
# 4  Excellent        8.8    Yes           Yes        Yes

# %%
## check the bottom rows
data.tail()
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 100196           No  48.02      No              No    Yes              13
# 100197          Yes  82.88      No              No     No              29
# 100198           No  39.46      No             Yes    Yes              23
# 100199           No  46.25     Yes             Yes    Yes               9
# 100200           No  39.26     Yes              No     No              10
#
#         MentalHealth DiffWalking     Sex  AgeCategory  \
# 100196            17          No  Female        45-49
# 100197            23          No    Male        75-79
# 100198             6         Yes    Male  80 or older
# 100199            14          No    Male        25-29
# 100200             5         Yes  Female        25-29
#
#                                   Race                 Diabetic  \
# 100196                           White  No, borderline diabetes
# 100197                           Other  No, borderline diabetes
# 100198                        Hispanic                      Yes
# 100199  American Indian/Alaskan Native                       No
# 100200                           Other  No, borderline diabetes
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 100196               No       Fair        6.4    Yes            No         No
# 100197              Yes  Very good       18.9    Yes           Yes         No
# 100198               No  Excellent       18.5    Yes            No        Yes
# 100199               No  Very good       22.7    Yes           Yes         No
# 100200              Yes       Fair        4.1     No            No        Yes

# %%
data.shape
# Out:
# (100201, 18)

# %%
## information about data
data.info
# Out:
# <bound method DataFrame.info of        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0               Yes  14.96     Yes             Yes     No               7
# 1               Yes  36.93     Yes             Yes     No               3
# 2                No  18.70     Yes              No    Yes              26
# 3               Yes  31.43     Yes             Yes    Yes              24
# 4               Yes  75.64      No              No    Yes               2
# ...             ...    ...     ...             ...    ...             ...
# 100196           No  48.02      No              No    Yes              13
# 100197          Yes  82.88      No              No     No              29
# 100198           No  39.46      No             Yes    Yes              23
# 100199           No  46.25     Yes             Yes    Yes               9
# 100200           No  39.26     Yes              No     No              10
#
#         MentalHealth DiffWalking     Sex  AgeCategory  \
# 0                  6         Yes  Female        25-29
# 1                 10          No  Female        30-34
# 2                 15          No    Male        70-74
# 3                 20          No  Female        40-44
# 4                 29          No    Male        35-39
# ...              ...         ...     ...          ...
# 100196            17          No  Female        45-49
# 100197            23          No    Male        75-79
# 100198             6         Yes    Male  80 or older
# 100199            14          No    Male        25-29
# 100200             5         Yes  Female        25-29
#
#                                   Race                 Diabetic  \
# 0                                White                      Yes
# 1                             Hispanic  No, borderline diabetes
# 2                             Hispanic                       No
# 3       American Indian/Alaskan Native  No, borderline diabetes
# 4                                White                       No
# ...                                ...                      ...
# 100196                           White  No, borderline diabetes
# 100197                           Other  No, borderline diabetes
# 100198                        Hispanic                      Yes
# 100199  American Indian/Alaskan Native                       No
# 100200                           Other  No, borderline diabetes
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0                   Yes       Fair       17.1    Yes           Yes        Yes
# 1                   Yes       Poor        2.7    Yes            No         No
# 2                    No       Poor       15.6    Yes           Yes        Yes
# 3                    No       Fair        1.4     No            No        Yes
# 4                   Yes  Excellent        8.8    Yes           Yes        Yes
# ...                 ...        ...        ...    ...           ...        ...
# 100196               No       Fair        6.4    Yes            No         No
# 100197              Yes  Very good       18.9    Yes           Yes         No
# 100198               No  Excellent       18.5    Yes            No        Yes
# 100199               No  Very good       22.7    Yes           Yes         No
# 100200              Yes       Fair        4.1     No            No        Yes
#
# [100201 rows x 18 columns]>

# %%
## statistical analysis
data.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  100201.000000   100201.000000  100201.000000  100201.000000
# mean       53.373302       14.503937      14.498239      12.490389
# std        23.878712        8.640423       8.658639       6.632122
# min        12.020000        0.000000       0.000000       1.000000
# 25%        32.760000        7.000000       7.000000       6.700000
# 50%        53.380000       14.000000      15.000000      12.500000
# 75%        73.950000       22.000000      22.000000      18.200000
# max        94.850000       29.000000      29.000000      24.000000

# %%
## missing values
data.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 100196    False
# 100197    False
# 100198    False
# 100199    False
# 100200    False
# Length: 100201, dtype: bool

# %%
len(data[data.duplicated()])
# Out:
# 0

# %%
data.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
##checking for counting of class in each column
for column in data.columns:
    print(data[column].value_counts())
# Out:
# HeartDisease
# Yes    50134
# No     50067
# Name: count, dtype: int64
# BMI
# 56.38    26
# 91.47    26
# 27.95    26
# 88.49    26
# 66.39    25
#          ..
# 23.75     3
# 29.15     3
# 65.14     3
# 34.33     2
# 91.36     2
# Name: count, Length: 8284, dtype: int64
# Smoking
# Yes    50445
# No     49756
# Name: count, dtype: int64
# AlcoholDrinking
# Yes    50435
# No     49766
# Name: count, dtype: int64
# Stroke
# Yes    50265
# No     49936
# Name: count, dtype: int64
# PhysicalHealth
# 8     3430
# 20    3401
# 9     3395
# 16    3392
# 19    3386
# 13    3385
# 12    3377
# 26    3369
# 29    3363
# 15    3355
# 23    3354
# 22    3347
# 28    3345
# 14    3343
# 2     3341
# 1     3337
# 10    3334
# 11    3332
# 6     3329
# 0     3328
# 17    3327
# 7     3323
# 24    3316
# 5     3305
# 18    3301
# 3     3287
# 21    3285
# 27    3277
# 25    3270
# 4     3267
# Name: count, dtype: int64
# MentalHealth
# 27    3442
# 16    3442
# 13    3419
# 5     3403
# 26    3397
# 21    3394
# 22    3390
# 7     3382
# 2     3377
# 8     3376
# 1     3374
# 18    3367
# 14    3362
# 28    3361
# 6     3360
# 3     3357
# 20    3342
# 9     3336
# 23    3333
# 17    3317
# 0     3299
# 19    3284
# 25    3280
# 10    3279
# 29    3274
# 11    3269
# 4     3257
# 15    3252
# 12    3247
# 24    3229
# Name: count, dtype: int64
# DiffWalking
# Yes    50153
# No     50048
# Name: count, dtype: int64
# Sex
# Female    50243
# Male      49958
# Name: count, dtype: int64
# AgeCategory
# 80 or older    7851
# 18-24          7850
# 55-59          7801
# 40-44          7789
# 25-29          7710
# 75-79          7697
# 70-74          7694
# 45-49          7680
# 60-64          7673
# 35-39          7641
# 50-54          7634
# 65-69          7591
# 30-34          7590
# Name: count, dtype: int64
# Race
# Hispanic                          16898
# Asian                             16834
# White                             16708
# American Indian/Alaskan Native    16650
# Black                             16582
# Other                             16529
# Name: count, dtype: int64
# Diabetic
# Yes (during pregnancy)     25171
# No, borderline diabetes    25077
# Yes                        25001
# No                         24952
# Name: count, dtype: int64
# PhysicalActivity
# No     50397
# Yes    49804
# Name: count, dtype: int64
# GenHealth
# Good         20342
# Poor         20180
# Fair         19986
# Excellent    19939
# Very good    19754
# Name: count, dtype: int64
# SleepTime
# 18.9    499
# 16.4    492
# 2.3     487
# 21.3    483
# 10.3    480
#        ...
# 23.2    395
# 1.3     394
# 18.6    388
# 24.0    234
# 1.0     196
# Name: count, Length: 231, dtype: int64
# Asthma
# Yes    50118
# No     50083
# Name: count, dtype: int64
# KidneyDisease
# Yes    50264
# No     49937
# Name: count, dtype: int64
# SkinCancer
# No     50426
# Yes    49775
# Name: count, dtype: int64

# %%
data['Diabetic'].value_counts()
# Out:
# Diabetic
# Yes (during pregnancy)     25171
# No, borderline diabetes    25077
# Yes                        25001
# No                         24952
# Name: count, dtype: int64

# %%
data=pd.get_dummies(data,columns=['Diabetic'],drop_first=True)

# %%
data.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0          Yes  14.96     Yes             Yes     No               7
# 1          Yes  36.93     Yes             Yes     No               3
# 2           No  18.70     Yes              No    Yes              26
# 3          Yes  31.43     Yes             Yes    Yes              24
# 4          Yes  75.64      No              No    Yes               2
#
#    MentalHealth DiffWalking     Sex AgeCategory  \
# 0             6         Yes  Female       25-29
# 1            10          No  Female       30-34
# 2            15          No    Male       70-74
# 3            20          No  Female       40-44
# 4            29          No    Male       35-39
#
#                              Race PhysicalActivity  GenHealth  SleepTime  \
# 0                           White              Yes       Fair       17.1
# 1                        Hispanic              Yes       Poor        2.7
# 2                        Hispanic               No       Poor       15.6
# 3  American Indian/Alaskan Native               No       Fair        1.4
# 4                           White              Yes  Excellent        8.8
#
#   Asthma KidneyDisease SkinCancer  Diabetic_No, borderline diabetes  \
# 0    Yes           Yes        Yes                             False
# 1    Yes            No         No                              True
# 2    Yes           Yes        Yes                             False
# 3     No            No        Yes                              True
# 4    Yes           Yes        Yes                             False
#
#    Diabetic_Yes  Diabetic_Yes (during pregnancy)
# 0          True                            False
# 1         False                            False
# 2         False                            False
# 3         False                            False
# 4         False                            False

# %%
binary_columns=["Smoking","AlcoholDrinking","Stroke","DiffWalking","PhysicalActivity","Asthma","KidneyDisease","SkinCancer"]
for col in binary_columns:
    data[col]=data[col].map({'Yes':1,"No":0})

# %%
##applying the get dummies method
data+pd.get_dummies(data,columns=['Sex','AgeCategory','Race','GenHealth'],drop_first=True)
print(data.head())
# Out:
#   HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0          Yes  14.96      NaN              NaN     NaN               7
# 1          Yes  36.93      NaN              NaN     NaN               3
# 2           No  18.70      NaN              NaN     NaN              26
# 3          Yes  31.43      NaN              NaN     NaN              24
# 4          Yes  75.64      NaN              NaN     NaN               2
#
#    MentalHealth  DiffWalking     Sex AgeCategory  \
# 0             6          NaN  Female       25-29
# 1            10          NaN  Female       30-34
# 2            15          NaN    Male       70-74
# 3            20          NaN  Female       40-44
# 4            29          NaN    Male       35-39
#
#                              Race  PhysicalActivity  GenHealth  SleepTime  \
# 0                           White               NaN       Fair       17.1
# 1                        Hispanic               NaN       Poor        2.7
# 2                        Hispanic               NaN       Poor       15.6
# 3  American Indian/Alaskan Native               NaN       Fair        1.4
# 4                           White               NaN  Excellent        8.8
#
#    Asthma  KidneyDisease  SkinCancer  Diabetic_No, borderline diabetes  \
# 0     NaN            NaN         NaN                             False
# 1     NaN            NaN         NaN                              True
# 2     NaN            NaN         NaN                             False
# 3     NaN            NaN         NaN                              True
# 4     NaN            NaN         NaN                             False
#
#    Diabetic_Yes  Diabetic_Yes (during pregnancy)
# 0          True                            False
# 1         False                            False
# 2         False                            False
# 3         False                            False
# 4         False                            False

# %%
##define the x and target
X=data.drop(columns=['HeartDisease'])
y=data['HeartDisease'].map({'Yes':1,"No":0})

# %%
X.head()
# Out:
#      BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 0  14.96      NaN              NaN     NaN               7             6
# 1  36.93      NaN              NaN     NaN               3            10
# 2  18.70      NaN              NaN     NaN              26            15
# 3  31.43      NaN              NaN     NaN              24            20
# 4  75.64      NaN              NaN     NaN               2            29
#
#    DiffWalking     Sex AgeCategory                            Race  \
# 0          NaN  Female       25-29                           White
# 1          NaN  Female       30-34                        Hispanic
# 2          NaN    Male       70-74                        Hispanic
# 3          NaN  Female       40-44  American Indian/Alaskan Native
# 4          NaN    Male       35-39                           White
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer  \
# 0               NaN       Fair       17.1     NaN            NaN         NaN
# 1               NaN       Poor        2.7     NaN            NaN         NaN
# 2               NaN       Poor       15.6     NaN            NaN         NaN
# 3               NaN       Fair        1.4     NaN            NaN         NaN
# 4               NaN  Excellent        8.8     NaN            NaN         NaN
#
#    Diabetic_No, borderline diabetes  Diabetic_Yes  \
# 0                             False          True
# 1                              True         False
# 2                             False         False
# 3                              True         False
# 4                             False         False
#
#    Diabetic_Yes (during pregnancy)
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)
